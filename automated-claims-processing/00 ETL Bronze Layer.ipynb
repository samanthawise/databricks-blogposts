# %% [markdown]
# # Bronze Layer
# - Landing of m4a files in Volumes
# - Creating a File Reference DataFrame

# %%
# %run "./resources/init"

# %%
spark.sql(f"CREATE CATALOG IF NOT EXISTS `{CATALOG}`")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS `{CATALOG}`.`{SCHEMA}`")
spark.sql(f"CREATE VOLUME IF NOT EXISTS `{CATALOG}`.`{SCHEMA}`.`{VOLUME}`")

# %%
audio_path = f"/Volumes/{CATALOG}/{SCHEMA}/{VOLUME}/raw_recordings/"
if not dbutils.fs.mkdirs(audio_path):
    dbutils.fs.mkdirs(audio_path)

# %%
import pyspark.sql.functions as F

file_reference_df = spark.createDataFrame(dbutils.fs.ls(f"/Volumes/{CATALOG}/{SCHEMA}/{VOLUME}/raw_recordings"))\
  .withColumn("file_path", F.expr("substring(path, 6, length(path))"))

display(file_reference_df)

file_reference_df.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable(f"{CATALOG}.{SCHEMA}.recordings_file_reference_bronze")
